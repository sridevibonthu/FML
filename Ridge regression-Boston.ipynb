# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
#Load the data
data = pd.read_csv("boston.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#Create feature and target array from such given data
X = data.drop('medv', axis=1).values
y = data['medv'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((379, 13), (127, 13))

# %%
#Fitting a Ridge regression model
reg = Ridge(alpha = 0.1)
reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.8)

# %%
#Evaluating the model on training data only
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred1 = reg.predict(X_train)
print(f'Performance of the model on training data :\n')
print(f'MAE = {mean_absolute_error(y_train, y_pred1)}')
print(f'MSE = {mean_squared_error(y_train, y_pred1)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_train, y_pred1))}')
print(f'R_2 = {r2_score(y_train, y_pred1)}')
# Out:
# Performance of the model on training data :
#
# MAE = 3.3508444619785367
# MSE = 22.47553681481111
# RMSE = 4.740837142827321
# R_2 = 0.7465595627785474

# %%
#Evaluating the model on training data only

y_pred2 = reg.predict(X_test)
print(f'Performance of the model on test data :\n')
print(f'MAE = {mean_absolute_error(y_test, y_pred2)}')
print(f'MSE = {mean_squared_error(y_test, y_pred2)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_test, y_pred2))}')
print(f'R_2 = {r2_score(y_test, y_pred2)}')
# Out:
# Performance of the model on test data :
#
# MAE = 3.047978582600649
# MSE = 22.419926818904173
# RMSE = 4.73496851297917
# R_2 = 0.6798394786800426

# %%
#By default ridge regression score method gives r_2 score
reg.score(X_test, y_test)
# Out:
# 0.6838049959091366
